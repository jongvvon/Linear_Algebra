# %% [markdown]
# 깊은 복사와 얕은 복사
#
# 파이썬은 모두 객체로 이루어짐
# 객체의 종류는 mutable 과 imtuable 로 이루어져있음
#  - mutable : 변경 가능한 객체
#   -> 리스트
#  - immutable : 변경 불가능한 객체
#   -> 숫자, 문자

# %%
# 깊은 복사 예제
x = 3
y = 3
print(x)
print(y)
print(id(x))
print(id(y))
# Out:
# 3
# 3
# 11527680
# 11527680

# %%
y = 7
print(x)
print(y)
print(id(x))
print(id(y))
# Out:
# 3
# 7
# 11527680
# 11527808
